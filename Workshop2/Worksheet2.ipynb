# %%
from google.colab import drive
drive.mount('/content/drive')
base = "/content/drive/MyDrive/Worksheet2_Concept_of_AI_&_Technologies/Dataset/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Examples Practice
#Example1
#Building blocks of Pandas:
import pandas as pd
#Creatign a  simple Series
data = [5,10,15,15]
series = pd.Series(data)
print(series)
# Out:
# 0     5
# 1    10
# 2    15
# 3    15
# dtype: int64

# %%
#Example2
#Default Index
import pandas as pd
series = pd.Series([3,4,6])
print(series.index)
#Userdefined:
series = pd.Series([3, 4, 6], index=['a', 'b', 'c'])
print(series)

dates = pd.date_range('2023-01-01', periods=3)
series = pd.Series([3, 4, 6], index=dates)
print(series)
print(series.index)
series.index = ['x', 'y', 'z']
print(series)
df = pd.DataFrame({'A': [1, 2]}, index=['row1', 'row2'])
df.reset_index(inplace=True)
print(df)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# a    3
# b    4
# c    6
# dtype: int64
# 2023-01-01    3
# 2023-01-02    4
# 2023-01-03    6
# Freq: D, dtype: int64
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03'], dtype='datetime64[ns]', freq='D')
# x    3
# y    4
# z    6
# dtype: int64
#   index  A
# 0  row1  1
# 1  row2  2

# %%
#Example 3
# Style-1
import pandas as pd

pd.DataFrame({
    'Bob': ['NOICE.', 'RED BUZZER.'],
    'Sue': ['GOOD JOB', 'CROSS']
})

# Style-2
pd.DataFrame({
    'Bob': ['NOICE.', 'RED BUZZER.'],
    'Sue': ['GOOD JOB.', 'CROSS.']
},
index=['Product A', 'Product B'])
# Out:
#                    Bob        Sue
# Product A       NOICE.  GOOD JOB.
# Product B  RED BUZZER.     CROSS.

# %%
#PROBLEM1

#STEP1

import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Worksheet2_Concept_of_AI_&_Technologies/Dataset/bank.csv")
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
#STEP2
#a
df.info()

objColumns = df.select_dtypes(include='object').columns
objColumns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# ...

# %%
#b
for col in objColumns:
  print(f"Column: {col}")
  print(df[col].unique())
# Out:
# Column: job
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# Column: marital
# ['married' 'single' 'divorced']
# Column: education
# ['tertiary' 'secondary' 'unknown' 'primary']
# Column: default
# ['no' 'yes']
# Column: housing
# ['yes' 'no']
# Column: loan
# ['no' 'yes']
# Column: contact
# ['unknown' 'cellular' 'telephone']
# Column: month
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# Column: poutcome
# ['unknown' 'failure' 'other' 'success']
# Column: y
# ['no' 'yes']

# %%
#c
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
#STEP3
dfNum = df.drop(columns=objColumns)

dfNum.to_csv("/content/drive/MyDrive/Worksheet2_Concept_of_AI_&_Technologies/Dataset/banknumericdata.csv",index = False)

dfNum.head()
# Out:
#    age  balance  day  duration  campaign  pdays  previous
# 0   58     2143    5       261         1     -1         0
# 1   44       29    5       151         1     -1         0
# 2   33        2    5        76         1     -1         0
# 3   47     1506    5        92         1     -1         0
# 4   33        1    5       198         1     -1         0

# %%
#STEP4
bankNum = pd.read_csv("/content/drive/MyDrive/Worksheet2_Concept_of_AI_&_Technologies/Dataset/banknumericdata.csv")

bankNum.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
#PROBLEM2
#STEP1
dfMEDBAY = pd.read_csv("/content/drive/MyDrive/Worksheet2_Concept_of_AI_&_Technologies/Dataset/medical_students_dataset.csv")
dfMEDBAY.head()
# Out:
#    Student ID   Age  Gender      Height     Weight Blood Type        BMI  \
# 0         1.0  18.0  Female  161.777924  72.354947          O  27.645835
# 1         2.0   NaN    Male  152.069157  47.630941          B        NaN
# 2         3.0  32.0  Female  182.537664  55.741083          A  16.729017
# 3         NaN  30.0    Male  182.112867  63.332207          B  19.096042
# 4         5.0  23.0  Female         NaN  46.234173          O        NaN
#
#    Temperature  Heart Rate  Blood Pressure  Cholesterol Diabetes Smoking
# 0          NaN        95.0           109.0        203.0       No     NaN
# 1    98.714977        93.0           104.0        163.0       No      No
# 2    98.260293        76.0           130.0        216.0      Yes      No
# 3    98.839605        99.0           112.0        141.0       No     Yes
# 4    98.480008        95.0             NaN        231.0       No      No

# %%
#STEP2
dfMEDBAY.info()
dfMEDBAY.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB
# Student ID        20000
# Age               20000
# Gender            20000
# Height            20000
# ...

# %%
#STEP3
numCols = ['Age','Height','Weight','BMI','Temperature','Heart Rate','Blood Pressure','Cholesterol']
dfMEDBAY[numCols] = dfMEDBAY[numCols].fillna(dfMEDBAY[numCols].median())

catCols = ["Gender", "Blood Type", "Diabetes", "Smoking"]
for col in catCols:
    dfMEDBAY[col] = dfMEDBAY[col].fillna(dfMEDBAY[col].mode()[0])

print("Filling up missing values:")
print(dfMEDBAY.isnull().sum())
# Out:
# Filling up missing values:
# Student ID        20000
# Age                   0
# Gender                0
# Height                0
# Weight                0
# Blood Type            0
# BMI                   0
# Temperature           0
# Heart Rate            0
# Blood Pressure        0
# Cholesterol           0
# Diabetes              0
# Smoking               0
# dtype: int64

# %%
#STEP4
dfMEDBAY= dfMEDBAY.drop_duplicates()
print("Remaning duplicates after removal:")
print(dfMEDBAY.duplicated().sum())
# Out:
# Remaning duplicates after removal:
# 0

# %%
#3.2 Titanic
#Problem1
dfTitanic= pd.read_csv("/content/drive/MyDrive/Worksheet2_Concept_of_AI_&_Technologies/Dataset/Titanic-Dataset.csv")

selection = ["Name","Pclass","Sex","Age","Fare","Survived"]
dfTpc1 = dfTitanic[selection]

dfTFirstClass = dfTpc1[dfTpc1["Pclass"] ==1]

meanFare = dfTFirstClass["Fare"].mean()
medianFare = dfTFirstClass["Fare"].median()
maxFare = dfTFirstClass["Fare"].max()
minFare = dfTFirstClass["Fare"].min()

print("Fare stats for FirstClass Passengers: ")
print(f"Mean fare: {meanFare}")
print(f"Median fare: {medianFare}")
print(f"Max fare: {maxFare}")
print(f"Min fare: {minFare}")
# Out:
# Fare stats for FirstClass Passengers:
# Mean fare: 84.1546875
# Median fare: 60.287499999999994
# Max fare: 512.3292
# Min fare: 0.0

# %%
#Problem2
null_age = dfTpc1["Age"].isnull().sum()
print(f"Number of null values in age: {null_age}")

new_age = dfTpc1.dropna(subset =["Age"])

print("Before", len(dfTpc1))
print("After", len(new_age))
# Out:
# Number of null values in age: 177
# Before 891
# After 714

# %%
#Problem3
titanic2 = dfTitanic.copy()

embarkeder = pd.get_dummies(titanic2["Embarked"], prefix="Embarked")

embarkeder = embarkeder.astype(int)

titanic2 = pd.concat([titanic2, embarkeder], axis=1)

titanic2 = titanic2.drop(columns =["Embarked"])

titanic2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin  Embarked_C  Embarked_Q  Embarked_S
# 0      0         A/5 21171   7.2500   NaN           0           0           1
# 1      0          PC 17599  71.2833   C85           1           0           0
# 2      0  STON/O2. 3101282   7.9250   NaN           0           0           1
# ...

# %%
#Problem4
import matplotlib.pyplot as plt

survival_by_sex = dfTitanic.groupby("Sex")["Survived"].mean()
print(survival_by_sex)

plt.bar(survival_by_sex.index, survival_by_sex.values, color=["purple", "green"])
plt.xlabel("Sex")
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Sex")
plt.show()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
#Problem5
survival_sex_embark = dfTitanic.groupby(["Sex", "Embarked"])["Survived"].mean()
# print(survival_sex_embark)

survival_sex_embark = survival_sex_embark.unstack()
print(survival_sex_embark)

survival_sex_embark.plot(kind ="bar")
plt.ylabel("Survival Rate")
plt.title("Survival Rate by Sex and Embarked")
plt.show()
# Out:
# Embarked         C         Q         S
# Sex
# female    0.876712  0.750000  0.689655
# male      0.305263  0.073171  0.174603
